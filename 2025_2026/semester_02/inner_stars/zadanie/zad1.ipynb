# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Zadanie 1
#
# Kolory w astronomii - Wskaźniki barwy
#
# 1.1
#
# Wykonać unormowany wykres funkcji Plancka dla gwiazdy gorącej 12 500 K oraz chłodniejszej 5 000 K. Na wykresie zaznaczyć wartości wskaźników (U: 3520.30 Å, B = 4384.51 Å, V = 5479.85 Å, R = 6846.67 Å) oraz pasma filtrów (szerokości filtrów) U, B, V, R:
#
# U: 3010–4100 Å
# B: 3709–5550 Å
# V: 4698–7204 Å
# R: 5233–9400 Å     według Johnson UBVR.

# %%
# Stałe fizyczne
h = 6.62607015e-34  #  Planck [J s]
c = 2.99792458e8    # prędkość światła [m/s]
k = 1.380649e-23     # Boltzmann [J/K]

def planck(wavelength, T):
    a = 2.0 * h * c**2
    b = h * c / (wavelength * k * T)
    intensity = a / (wavelength**5 * (np.exp(b) - 1.0))
    return intensity

lambda_min = 10e-10  
lambda_max = 20000e-10 
wavelengths = np.linspace(lambda_min, lambda_max, 1000)

T_hot = 12500
T_cool = 5000

B_hot = planck(wavelengths, T_hot)
B_cool = planck(wavelengths, T_cool)

B_hot /= B_hot.max()
B_cool /= B_cool.max()

filters = {
    'U': {'center': 3520.30e-10, 'range': (3010e-10, 4100e-10), 'color': 'violet'},
    'B': {'center': 4384.51e-10, 'range': (3709e-10, 5550e-10), 'color': 'blue'},
    'V': {'center': 5479.85e-10, 'range': (4698e-10, 7204e-10), 'color': 'green'},
    'R': {'center': 6846.67e-10, 'range': (5233e-10, 9400e-10), 'color': 'red'},
}

plt.figure(figsize=(10,6))
plt.plot(wavelengths*1e10, B_hot, label='T = 12 500 K', color='orange')
plt.plot(wavelengths*1e10, B_cool, label='T = 5 000 K', color='deepskyblue')

for name, f in filters.items():
    plt.axvspan(f['range'][0]*1e10, f['range'][1]*1e10, color=f['color'], alpha=0.1, label=f'Filter {name}')
    plt.axvline(f['center']*1e10, color=f['color'], linestyle='--', label=f'{name} ({f["center"]*1e10:.0f} Å)')

plt.xlabel(r'Wavelength [$\rm \AA$]')
plt.ylabel('Normalised flux density')
# plt.title('Unormowane krzywe Plancka dla 12 500 K i 5 000 K z filtrami UBVR (Johnson)')
plt.legend(loc='upper right', fontsize=8, ncol=2)
plt.xlim(0, 20000)
plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_11.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)
# Out:
# /tmp/ipykernel_34078/1083980696.py:9: RuntimeWarning: overflow encountered in exp
#   intensity = a / (wavelength**5 * (np.exp(b) - 1.0))

# %% [markdown]
# Obliczyć wartości wskaźnika B-V dla gwiazdy gorącej i chłodnej:

# %% [markdown]
# b) obliczyć według wzoru (z funkcji Planck)

# %%
B_V_hot = -2.5*np.log10(planck(4385e-10, T_hot) / planck(5480e-10, T_hot))
B_V_cold = -2.5*np.log10(planck(4385e-10, T_cool) / planck(5480e-10, T_cool))

print(B_V_hot)
print(B_V_cold)
print("Dla gorącej kolor jest ujemny, a dla chłodnej - dodatni")
# Out:
# -0.5805514325666852
# 0.21771259488109634
# Dla gorącej kolor jest ujemny, a dla chłodnej - dodatni

# %% [markdown]
# a) odczytać z wykresu i do wzory

# %% [markdown]
# # TBD

# %% [markdown]
# Wynik końcowy
#
# Wykres: dwie krzywe Plancka z zaznaczonymi filtrami i ich szerokościami.
# Dla której gwiazdy wskaźnik barwy ma wartość pozytywną, a dla której negatywną?
# Podać wartości B–V z punktów a) i b).

# %% [markdown]
# ---------------------------------------------------------------------------------------

# %% [markdown]
# 1.2 Obliczyć wskaźniki barwy B–V dla 10 różnych temperatur:
#
# 40 000 K, 30 000 K, 20 000 K, 17 500 K, 15 000 K, 12 500 K, 10 000 K,  7 500 K
# 5 000 K, 2 500 K
#
# w tym dla Wegi (T_Wegi = 9 790 K) i następnie wykreślić zależność temperatury od B-V.
#
# Wega jest używana jaka gwiazda referencyjna w systemie magnitudo, jest punktem Zero do skali. U = B = V = R = I = 0

# %%
def B_V(T):
    return -2.5*np.log10(planck(4385e-10, T) / planck(5480e-10, T))

T = np.array([40000, 30000, 20000, 17500, 15000, 12500, 10000, 9790, 7500, 5000, 2500])
B_V_values = B_V(T)

fig, ax = plt.subplots(1, 1, figsize=(8,5))
ax.plot(T, B_V_values, marker='o', color='purple')
ax.set_ylabel('B-V')
ax.set_xlabel('Temperature [K]')
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_12.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)

# %% [markdown]
# Taking into the Vega, as reference star with U = B = V = R = I = 0, we can calculate the B-V index for the other stars:

# %%
def B_V_Vega(T):
    return -2.5*np.log10(planck(4385e-10, T) * planck(5480e-10, 9790) / planck(5480e-10, T) / planck(4385e-10, 9790))

T = np.array([40000, 30000, 20000, 17500, 15000, 12500, 10000, 9790, 7500, 5000, 2500])
B_V_values = B_V_Vega(T)

fig, ax = plt.subplots(1, 1, figsize=(8,5))
ax.plot(T, B_V_values, marker='o', color='purple')
ax.set_ylabel('B-V (Vega reference)')
ax.set_xlabel('Temperature [K]')
plt.show()

# %% [markdown]
# -------------------------------------------------------------------------------------------

# %% [markdown]
# 1.3
#
# Sprawdzić wskaźniki barwy B-V oraz temperaturę dla wybranych gwiazd z danymi z obserwacji (nanieść na wykres z punktu 1.2), dane znajdują się w pliku:
#
# / SZUFLADA / MP / BiEG / B-V / B-V-dane_obserwacje.dat
#
# Pytanie: Dlaczego jest różnica pomiędzy wartościami obliczonymi a z obserwacji?
#
# Z wykresu odczytać wartości temperatur dla gwiazd: Spica, Rigel, Słońce (B-V = 0.64) i Antares (wartości wskaźników B-V z literatury baza Simbad)  i porównać z Teff dostępnymi w literaturze.
#
# Zaznaczyć gwiazdy na wykresie.

# %%
import pandas as pd
path_to_data = "/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/data/B-V-dane_obserwacje.dat"
data = pd.read_csv(path_to_data, sep='\s+', comment='#', header=0)

data = data[data['B-V'] != '...']
data['B-V'] = data['B-V'].astype(float)

# %%
def B_V_Vega(T):
    return -2.5*np.log10(planck(4385e-10, T) * planck(5480e-10, 9790) / planck(5480e-10, T) / planck(4385e-10, 9790))

T = np.array([40000, 30000, 20000, 17500, 15000, 12500, 10000, 9790, 7500, 5000, 2500])
B_V_values = B_V_Vega(T)

fig, ax = plt.subplots(1, 1, figsize=(8,5))
ax.plot(T, B_V_values, marker='o', color='purple', label='Theoretical B-V')
ax.scatter(data['Teff'], data['B-V'], color='red', label='Observational data')
ax.set_ylabel('B-V (Vega reference)')
ax.set_xlabel('Temperature [K]')
ax.legend()
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_13.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)

# %%
# Z Simbad:
            # TeffSimbad TeffWykres B-VLiteratura
# Spica       24683      14000   -0.23
# Rigel       12622      10000   -0.03
# Sun         5778       5000   0.64 
# Antares     3200       3000   1.84

# %%
def B_V_Vega(T):
    return -2.5*np.log10(planck(4385e-10, T) * planck(5480e-10, 9790) / planck(5480e-10, T) / planck(4385e-10, 9790))

T = np.array([40000, 30000, 20000, 17500, 15000, 12500, 10000, 9790, 7500, 5000, 2500])
B_V_values = B_V_Vega(T)

temperatures = [24683, 12622, 5778, 3200]
names = ['Spica', 'Rigel', 'Sun', 'Antares']
B_V_obs = [-0.23, -0.03, 0.64, 1.84]

fig, ax = plt.subplots(1, 1, figsize=(8,5))
ax.plot(T, B_V_values, marker='o', color='purple', label='Theoretical B-V')
ax.scatter(data['Teff'], data['B-V'], color='red', label='Observational data')
ax.scatter(temperatures, B_V_obs, color='orange', s=30, marker='x')

for i in range(len(temperatures)):
    ax.text(temperatures[i], B_V_obs[i], names[i], fontsize=12, ha='left', va='bottom')
ax.set_ylabel('B-V (Vega reference)')

ax.tick_params(axis='x', labelrotation=90)
ax.set_xticks(np.arange(0, 45000, 1000))
ax.set_xlabel('Temperature [K]')
ax.legend()
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_13.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)

# %% [markdown]
# Wynik końcowy 1.2 i 1.3
#
# - Wykres B-V vs Teff (policzone wartości dla 10 gwiazd + Wega, wartości z obs z pliku zaznaczone gwiazdy z punktu 1.3)
# - Tabelka tak jak na tablicy → gwiazdy Teff_literatura, Teff_wykres, B-V_literatura
# - Odpowiedzieć na pytanie:
#     Różnica wynika z dwóch powodów: gwiazdy w rzeczywistości również posiadają serie linii absorpcji, np. Balmer break + fakt, że dla obliczenia kolorów korzystaliśmy z centralnej długości fali, a nie całego pasma filtru.

# %% [markdown]
# --------------------------------------------------------------------------------------------

# %% [markdown]
# 1.4
#
# Wykonać wykres dwuwskaźnikowy (U–B vs B–V) dla gwiazd klasy jasności V i dla nadolbrzymów Ia.
#
# Na wykresie trzeba umieścić:
# wartości z pliku,
# obliczone dla: T = 40 000 K, 20 000 K, 10 000 K, 5 000 K i 3 000 / 2 500 K  (punkty połączyć linią).
#
# Wykres: os x: B-V, os y: U-B [wartości od dodatnich do ujemnych].
#
# Dane do wykresu: / SZUFLADA / MP / BiEG / B-V / Dane_B-V_Typ_Widmowy.dat
#
# Pytanie: Dlaczego jest różnica pomiędzy wartościami dla klasy V i I oraz punktami z funkcji Plancka?
#
# **Bo funkcja Plancka nie uwzględnia poprawki dla Vegi, która jest używana jako punkt odniesienia dla kolorów + Planck nie jest idealną reprezentacją rozkładu energii gwiazdy, który omija linie absorpcyjne, np.**
#
# Tablica: Obliczenie stałych CU-B i CV-B do uwzględnienia poprawki Wegi.

# %%
import pandas as pd
path_to_data = "/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/data/Dane_B-V_Typ_Widmowy.dat"
data = pd.read_csv(path_to_data, sep='\s+', comment='#', header=0)

data
# Out:
#    Type  B-V_V  B-V_Ia  U-B_V  U-B_Ia
# 0    O5  -0.33   -0.31  -1.19   -1.17
# 1     6  -0.33   -0.31  -1.17   -1.16
# 2     7  -0.32   -0.31  -1.15   -1.14
# 3     8  -0.32   -0.29  -1.14   -1.13
# 4     9  -0.31   -0.27  -1.12   -1.13
# 5    B0  -0.30   -0.23  -1.08   -1.06
# 6     1  -0.26   -0.19  -0.95   -1.00
# 7     2  -0.24   -0.17  -0.84   -0.93
# 8     3  -0.20   -0.13  -0.71   -0.83
# 9     5  -0.17   -0.10  -0.58   -0.72
# 10    6  -0.15   -0.08  -0.50   -0.69
# 11    7  -0.13   -0.05  -0.43   -0.63
# 12    8  -0.11   -0.03  -0.34   -0.55
# 13    9  -0.07   -0.02  -0.20   -0.49
# 14   A0  -0.02   -0.01  -0.02   -0.38
# 15    1  -0.01    0.02  -0.02    0.29
# 16    2   0.05    0.03   0.05   -0.25
# 17    3   0.08    0.06   0.08   -0.14
# 18    5   0.15    0.11   0.10   -0.08
# 19    7   0.20    0.12   0.10    0.00
# 20    8   0.25    0.14   0.09    0.11
# 21   F0   0.30    0.17   0.03    0.15
# 22    2   0.35    0.23   0.00    0.18
# 23    5   0.44    0.32   0.02    0.27
# 24    8   0.52    0.56   0.02    0.41
# 25   G0   0.58    0.76   0.06    0.52
# 26    2   0.63    0.87   0.12    0.63
# 27    5   0.68    1.02   0.20    0.83
# 28    8   0.74    1.14   0.30    1.05
# 29   K0   0.81    1.25   0.45    1.17
# 30    1   0.86    1.32   0.54    1.28
# 31    2   0.91    1.36   0.64    1.32
# 32    3   0.96    1.46   0.80    1.60
# 33    5   1.15    1.60   1.98    1.80
# 34    7   1.33    1.63   1.21    1.84
# 35   M0   1.40    1.67   1.22    1.90
# 36    1   1.46    1.69   1.21    1.90
# 37    2   1.49    1.69   1.18    1.95
# 38    3   1.51    1.69   1.16    1.95
# 39    4   1.54    1.76   1.15    2.00
# 40    5   1.64    1.80   1.24    1.60

# %%
fig, ax = plt.subplots(1, 1, figsize=(8,5))
ax.plot(data['B-V_V'], data['U-B_V'], marker='o', color='purple', label='Data for luminosity class V')
ax.plot(data['B-V_Ia'], data['U-B_Ia'], marker='o', color='orange', label='Data for luminosity class Ia')
ax.set_xlabel('B-V')
ax.set_ylabel('U-B')
ax.legend()
ax.xaxis.set_inverted(True)
ax.yaxis.set_inverted(True)
plt.show()

# %%
width_U = 109 #nm
width_B = 184 #nm
width_V = 250 #nm

def U_B(T):
    return -2.5*np.log10(planck(3520.30e-10, T) * width_U / (planck(4384.51e-10, T) * width_B))

def B_V(T):
    return -2.5*np.log10(planck(4384.51e-10, T) * width_B / (planck(5480.00e-10, T) * width_V))

print(U_B(40000))
print(B_V(40000))

# U_B dla O5 z obserwacji wynosi -1.19 (dla V)
# B-V dla O5 z obserwacji wynosi -0.33 (dla V)

C_UB = (-1.19) - U_B(40000)
C_BV = (-0.33) - B_V(40000)

print("C_UB (nowe szerokosci)", C_UB)
print("C_BV (nowe szerokosci)", C_BV)
# Out:
# -0.25905533836380995
# -0.5359030774783959
# C_UB (nowe szerokosci) -0.93094466163619
# C_BV (nowe szerokosci) 0.20590307747839592

# %%
width_U = 68 #nm
width_B = 98 #nm
width_V = 89 #nm

print(U_B(42000))
print(B_V(42000))

# U_B dla O5 z obserwacji wynosi -1.19 (dla V)
# B-V dla O5 z obserwacji wynosi -0.33 (dla V)

C_UB = (-1.19) - U_B(42000)
C_BV = (-0.33) - B_V(42000)

print("C_UB (stare szerokosci)", C_UB)
print("C_BV (stare szerokosci)", C_BV)
# Out:
# -0.4374660646957126
# -0.9785392927028452
# C_UB (stare szerokosci) -0.7525339353042874
# C_BV (stare szerokosci) 0.6485392927028453

# %% [markdown]
# Generujemy wykres U-B vs B-V dla danych z pliku i obliczonych punktów z funkcji Plancka (uwzględniając poprawkę dla nowych filtrów) dla klasy V i Ia.

# %%
T = [40000, 20000, 10000, 5000, 3000, 2500]

width_U = 109 #nm
width_B = 184 #nm
width_V = 250 #nm

def U_B_corr(T):
    return -2.5*np.log10(planck(3520.30e-10, T) * width_U / (planck(4384.51e-10, T) * width_B)) - 0.93

def B_V_corr(T):
    return -2.5*np.log10(planck(4384.51e-10, T) * width_B / (planck(5480.00e-10, T) * width_V)) + 0.21

fig, ax = plt.subplots(1, 1, figsize=(8,5))
ax.plot(data['B-V_V'], data['U-B_V'], marker='o', color='purple', label='Data for luminosity class V')
ax.plot(data['B-V_Ia'], data['U-B_Ia'], marker='o', color='orange', label='Data for luminosity class Ia')
ax.plot([B_V_corr(t) for t in T], [U_B_corr(t) for t in T], marker='*', color='blue', label='Planck function with corrections')
for t in T:
    ax.text(B_V_corr(t), U_B_corr(t), f'T={t}K', fontsize=9, ha='left', va='bottom')

ax.set_xlabel('B-V')
ax.set_ylabel('U-B')
ax.legend()
# ax.xaxis.set_inverted(True)
ax.yaxis.set_inverted(True)
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_14.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)

# %% [markdown]
# ### 1.5
#
# Porównanie krzywej teoretycznej funkcji Plancka i wskaźników barwy z wartościami otrzymanymi z widm syntetycznych
# oraz widm gwiazd standardowych
#
# ad 1.1
#
# Modyfikacja zadania 1.1:

# %% [markdown]
# #### I Opcja Planck
#
#  wykres dla Teff_1 = 9000, Teff_2 = 7000, Teff_3 = 5000 K
# policzyć B-V dla 3 wartości Teff z podpunktu a)
#
# B-V(9000) = -0.387, B-V(7000) = -0.177. B-V(5000) = +0.218
#
# B: 3709–5550 Å
# V: 4698–7204 Å

# %%
# Stałe fizyczne
h = 6.62607015e-34  #  Planck [J s]
c = 2.99792458e8    # prędkość światła [m/s]
k = 1.380649e-23     # Boltzmann [J/K]

def planck(wavelength, T):
    a = 2.0 * h * c**2
    b = h * c / (wavelength * k * T)
    intensity = a / (wavelength**5 * (np.exp(b) - 1.0))
    return intensity

lambda_min = 10e-10  
lambda_max = 20000e-10 
wavelengths = np.linspace(lambda_min, lambda_max, 1000)

T_hot = 9000
T_mid = 7000
T_cool = 5000

B_hot = planck(wavelengths, T_hot)
B_mid = planck(wavelengths, T_mid)
B_cool = planck(wavelengths, T_cool)

B_hot /= B_hot.max()
B_mid /= B_mid.max()
B_cool /= B_cool.max()

filters = {
    # 'U': {'center': 3520.30e-10, 'range': (3010e-10, 4100e-10), 'color': 'violet'},
    'B': {'center': 4384.51e-10, 'range': (3709e-10, 5550e-10), 'color': 'blue'},
    'V': {'center': 5479.85e-10, 'range': (4698e-10, 7204e-10), 'color': 'green'},
    # 'R': {'center': 6846.67e-10, 'range': (5233e-10, 9400e-10), 'color': 'red'},
}

plt.figure(figsize=(10,6))
plt.plot(wavelengths*1e10, B_hot, label='T = 9 000 K', color='orange')
plt.plot(wavelengths*1e10, B_mid, label='T = 7 000 K', color='green')
plt.plot(wavelengths*1e10, B_cool, label='T = 5 000 K', color='deepskyblue')

for name, f in filters.items():
    plt.axvspan(f['range'][0]*1e10, f['range'][1]*1e10, color=f['color'], alpha=0.1, label=f'Filter {name}')
    plt.axvline(f['center']*1e10, color=f['color'], linestyle='--', label=f'{name} ({f["center"]*1e10:.0f} Å)')

plt.xlabel(r'Wavelength [$\rm \AA$]')
plt.ylabel('Normalised flux density')
# plt.title('Unormowane krzywe Plancka dla 9 000 K, 7 000 K i 5 000 K z filtrami UBVR (Johnson)')
plt.legend(loc='upper right', fontsize=12, ncol=2)
plt.xlim(0, 20000)
plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_151.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)
# Out:
# /tmp/ipykernel_34078/3546435724.py:9: RuntimeWarning: overflow encountered in exp
#   intensity = a / (wavelength**5 * (np.exp(b) - 1.0))

# %%
B_V_hot = -2.5*np.log10(planck(4385e-10, T_hot) / planck(5480e-10, T_hot))
B_V_mid = -2.5*np.log10(planck(4385e-10, T_mid) / planck(5480e-10, T_mid))
B_V_cold = -2.5*np.log10(planck(4385e-10, T_cool) / planck(5480e-10, T_cool))

print("B_V_T=9000 K: ", B_V_hot)
print("B_V_T=7000 K: ", B_V_mid)
print("B_V_T=5000 K: ", B_V_cold)
# Out:
# B_V_T=9000 K:  -0.3875544681002929
# B_V_T=7000 K:  -0.17745131414129572
# B_V_T=5000 K:  0.21771259488109634

# %% [markdown]
# #### II Opcja - widmo syntetyczne (logg = 4.0, vsini = 10, R~80 000, M/H =0.0, vmic =1, vmac=2)
#
# wykres dla Teff_s = 9000, 7000 i 5000 K
# policzyć B-V_TS1,  B-V_TS2, B-V_TS3
# dla Teff = 7000 dwa widma z różnymi metalicznościami M/H = +0.5  i M/H = -0.5
# B-V_TS2_0.5, B-V_TS2_-0.5
#
# Uwagi:
# na 3 osobnych wykresach 3 różne Teff (Planck + Planck*Synt)
#
# Tablica z wynikami z zajęć: 20-03-2026

# %% [markdown]
# ##### Hot star

# %%
import os
import pandas as pd

# %%
path_to_files = r"/media/olehryz/Elements/databases/UNIV/Dane_do_Zadania_z_wskaznikami_barwy"

synthetic_data_path = os.path.join(path_to_files, "synthe_9000.0_4.0_0.0_0.0_1.07.txt")

spectrum_data_hot = pd.read_csv(synthetic_data_path, delim_whitespace=True, comment='#', header=0)

spectrum_data_hot
# Out:
#         waveobs          flux  err
# 0       300.000  1.000000e-10  0.0
# 1       300.001  7.943644e-01  0.0
# 2       300.002  7.801127e-01  0.0
# 3       300.003  7.641373e-01  0.0
# 4       300.004  7.497003e-01  0.0
# ...         ...           ...  ...
# 699995  999.995  9.929786e-01  0.0
# 699996  999.996  9.930836e-01  0.0
# 699997  999.997  9.931882e-01  0.0
# 699998  999.998  9.932903e-01  0.0
# 699999  999.999  1.000000e-10  0.0
#
# [700000 rows x 3 columns]

# %%
# Stałe fizyczne
h = 6.62607015e-34  #  Planck [J s]
c = 2.99792458e8    # prędkość światła [m/s]
k = 1.380649e-23     # Boltzmann [J/K]

def planck(wavelength, T):
    a = 2.0 * h * c**2
    b = h * c / (wavelength * k * T)
    intensity = a / (wavelength**5 * (np.exp(b) - 1.0))
    return intensity

lambda_min = 300e-9  
lambda_max = 1000e-9 
wavelengths = np.arange(lambda_min, lambda_max, 0.001e-9)

T_hot = 9000

B_hot = planck(wavelengths, T_hot)
B_hot_synth = planck(wavelengths, T_hot)*spectrum_data_hot["flux"].values

B_hot /= B_hot.max()
B_hot_synth /= B_hot_synth.max()

filters = {
    # 'U': {'center': 3520.30e-10, 'range': (3010e-10, 4100e-10), 'color': 'violet'},
    'B': {'center': 4384.51e-10, 'range': (3709e-10, 5550e-10), 'color': 'blue'},
    'V': {'center': 5479.85e-10, 'range': (4698e-10, 7204e-10), 'color': 'green'},
    # 'R': {'center': 6846.67e-10, 'range': (5233e-10, 9400e-10), 'color': 'red'},
}

plt.figure(figsize=(10,6))
plt.plot(wavelengths*1e10, B_hot, label='T = 9 000 K', color='orange')
plt.plot(wavelengths*1e10, B_hot_synth, label='T = 9 000 K (synth)', color='red')

for name, f in filters.items():
    plt.axvspan(f['range'][0]*1e10, f['range'][1]*1e10, color=f['color'], alpha=0.1, label=f'Filter {name}')
    # plt.axvline(f['center']*1e10, color=f['color'], linestyle='--', label=f'{name} ({f["center"]*1e10:.0f} Å)')

plt.xlabel(r'Wavelength [$\rm \AA$]')
plt.ylabel('Normalised flux density')
# plt.title('Unormowane krzywe Plancka dla 9 000 K, 7 000 K i 5 000 K z filtrami UBVR (Johnson)')
plt.legend(loc='upper right', fontsize=12, ncol=2)
plt.xlim(3000, 10000)
plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_1521.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)

# %%
def flux_calc(flux, wavelength, wave_start, wave_end):
    mask = (wavelength >= wave_start) & (wavelength <= wave_end)
    return np.trapz(flux[mask], wavelength[mask])

B_V_hot_synth_flux = -2.5*np.log10(flux_calc(B_hot_synth, wavelengths, 3709e-10, 5550e-10) / flux_calc(B_hot_synth, wavelengths, 4698e-10, 7204e-10))
B_V_hot_flux = -2.5*np.log10(flux_calc(B_hot, wavelengths, 3709e-10, 5550e-10) / flux_calc(B_hot, wavelengths, 4698e-10, 7204e-10))
B_V_hot_synth_centroid = -2.5*np.log10(planck(4384.51e-10, T_hot) / planck(5480e-10, T_hot))

print("Synthetic 9000K B-V (flux): ", B_V_hot_synth_flux)
print("Planck 9000K B-V (flux): ", B_V_hot_flux)
print("Synthetic 9000K B-V (centroid): ", B_V_hot_synth_centroid)
# Out:
# Synthetic 9000K B-V (flux):  0.01468255463051453
# Planck 9000K B-V (flux):  -0.12215053624738473
# Synthetic 9000K B-V (centroid):  -0.38770690869819663

# %% [markdown]
# ##### Warm star

# %%
path_to_files = r"/media/olehryz/Elements/databases/UNIV/Dane_do_Zadania_z_wskaznikami_barwy"

synthetic_data_path_warm = os.path.join(path_to_files, "synthe_7000.0_4.0_0.0_0.0_1.0.txt")
synthetic_data_path_warm_plus = os.path.join(path_to_files, "synthe_7000.0_4.0_M_H_0.5_0.0_1.07.txt")
synthetic_data_path_warm_minus = os.path.join(path_to_files, "synthe_7000.0_4.0_M_H_-0.5_0.0_1.07.txt")

spectrum_data_warm = pd.read_csv(synthetic_data_path_warm, delim_whitespace=True, comment='#', header=0)
spectrum_data_warm_plus = pd.read_csv(synthetic_data_path_warm_plus, delim_whitespace=True, comment='#', header=0)
spectrum_data_warm_minus = pd.read_csv(synthetic_data_path_warm_minus, delim_whitespace=True, comment='#', header=0)

spectrum_data_warm
# Out:
#         waveobs          flux  err
# 0       300.000  1.000000e-10  0.0
# 1       300.001  6.562695e-01  0.0
# 2       300.002  6.368061e-01  0.0
# 3       300.003  6.152941e-01  0.0
# 4       300.004  5.956493e-01  0.0
# ...         ...           ...  ...
# 699995  999.995  9.856195e-01  0.0
# 699996  999.996  9.858039e-01  0.0
# 699997  999.997  9.859942e-01  0.0
# 699998  999.998  9.861866e-01  0.0
# 699999  999.999  1.000000e-10  0.0
#
# [700000 rows x 3 columns]

# %%
# Stałe fizyczne
h = 6.62607015e-34  #  Planck [J s]
c = 2.99792458e8    # prędkość światła [m/s]
k = 1.380649e-23     # Boltzmann [J/K]

def planck(wavelength, T):
    a = 2.0 * h * c**2
    b = h * c / (wavelength * k * T)
    intensity = a / (wavelength**5 * (np.exp(b) - 1.0))
    return intensity

lambda_min = 300e-9  
lambda_max = 1000e-9 
wavelengths = np.arange(lambda_min, lambda_max, 0.001e-9)

T_warm = 7000

B_warm = planck(wavelengths, T_warm)
B_warm_synth = planck(wavelengths, T_warm)*spectrum_data_warm["flux"].values
B_warm_plus_synth = planck(wavelengths, T_warm)*spectrum_data_warm_plus["flux"].values
B_warm_minus_synth = planck(wavelengths, T_warm)*spectrum_data_warm_minus["flux"].values

B_warm /= B_warm.max()
B_warm_synth /= B_warm_synth.max()
B_warm_plus_synth /= B_warm_plus_synth.max()
B_warm_minus_synth /= B_warm_minus_synth.max()

filters = {
    # 'U': {'center': 3520.30e-10, 'range': (3010e-10, 4100e-10), 'color': 'violet'},
    'B': {'center': 4384.51e-10, 'range': (3709e-10, 5550e-10), 'color': 'blue'},
    'V': {'center': 5479.85e-10, 'range': (4698e-10, 7204e-10), 'color': 'green'},
    # 'R': {'center': 6846.67e-10, 'range': (5233e-10, 9400e-10), 'color': 'red'},
}

plt.figure(figsize=(10,6))
plt.plot(wavelengths*1e10, B_warm, label='T = 7 000 K', color='orange')
plt.plot(wavelengths*1e10, B_warm_synth, label='T = 7 000 K (synth)', color='red')
plt.plot(wavelengths*1e10, B_warm_plus_synth, label='T = 7 000 K + 0.5 (synth)', color='blue')
plt.plot(wavelengths*1e10, B_warm_minus_synth, label='T = 7 000 K - 0.5 (synth)', color='green')

for name, f in filters.items():
    plt.axvspan(f['range'][0]*1e10, f['range'][1]*1e10, color=f['color'], alpha=0.1, label=f'Filter {name}')
    # plt.axvline(f['center']*1e10, color=f['color'], linestyle='--', label=f'{name} ({f["center"]*1e10:.0f} Å)')

plt.xlabel(r'Wavelength [$\rm \AA$]')
plt.ylabel('Normalised flux density')
# plt.title('Unormowane krzywe Plancka dla 9 000 K, 7 000 K i 5 000 K z filtrami UBVR (Johnson)')
plt.legend(loc='upper right', fontsize=12, ncol=2)
plt.xlim(3000, 10000)
plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_1522.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)

# %%
B_V_warm_synth_flux = -2.5*np.log10(flux_calc(B_warm_synth, wavelengths, 3709e-10, 5550e-10) / flux_calc(B_warm_synth, wavelengths, 4698e-10, 7204e-10))
B_V_warm_synth_flux_plus = -2.5*np.log10(flux_calc(B_warm_plus_synth, wavelengths, 3709e-10, 5550e-10) / flux_calc(B_warm_plus_synth, wavelengths, 4698e-10, 7204e-10))
B_V_warm_synth_flux_minus = -2.5*np.log10(flux_calc(B_warm_minus_synth, wavelengths, 3709e-10, 5550e-10) / flux_calc(B_warm_minus_synth, wavelengths, 4698e-10, 7204e-10))
B_V_warm_flux = -2.5*np.log10(flux_calc(B_warm, wavelengths, 3709e-10, 5550e-10) / flux_calc(B_warm, wavelengths, 4698e-10, 7204e-10))
B_V_warm_synth_centroid = -2.5*np.log10(planck(4384.51e-10, T_warm) / planck(5480e-10, T_warm))

print("Synthetic 7000K B-V (flux): ", B_V_warm_synth_flux)
print("Synthetic 7000K +0.5 B-V (flux): ", B_V_warm_synth_flux_plus)
print("Synthetic 7000K -0.5 B-V (flux): ", B_V_warm_synth_flux_minus)
print("Planck 7000K B-V (flux): ", B_V_warm_flux)
print("Synthetic 7000K B-V (centroid): ", B_V_warm_synth_centroid)
# Out:
# Synthetic 7000K B-V (flux):  0.21385185987015654
# Synthetic 7000K +0.5 B-V (flux):  0.25607170177522326
# Synthetic 7000K -0.5 B-V (flux):  0.18595640617988016
# Planck 7000K B-V (flux):  0.09073789259743564
# Synthetic 7000K B-V (centroid):  -0.1774839326105036

# %% [markdown]
# ##### Cool star

# %%
path_to_files = r"/media/olehryz/Elements/databases/UNIV/Dane_do_Zadania_z_wskaznikami_barwy"

synthetic_data_path_cool = os.path.join(path_to_files, "synthe_5000.0_4.0_0.0_0.0_1.07.txt")

spectrum_data_cool = pd.read_csv(synthetic_data_path_cool, delim_whitespace=True, comment='#', header=0)

spectrum_data_cool = spectrum_data_cool[spectrum_data_cool["waveobs"] <= 999.999]

# %%
# Stałe fizyczne
h = 6.62607015e-34  #  Planck [J s]
c = 2.99792458e8    # prędkość światła [m/s]
k = 1.380649e-23     # Boltzmann [J/K]

def planck(wavelength, T):
    a = 2.0 * h * c**2
    b = h * c / (wavelength * k * T)
    intensity = a / (wavelength**5 * (np.exp(b) - 1.0))
    return intensity

lambda_min = 300e-9  
lambda_max = 1000e-9 
wavelengths = np.arange(lambda_min, lambda_max, 0.001e-9)

T_cool = 5000

B_cool = planck(wavelengths, T_cool)
B_cool_synth = planck(wavelengths, T_cool)*spectrum_data_cool["flux"].values

B_cool /= B_cool.max()
B_cool_synth /= B_cool_synth.max()

filters = {
    # 'U': {'center': 3520.30e-10, 'range': (3010e-10, 4100e-10), 'color': 'violet'},
    'B': {'center': 4384.51e-10, 'range': (3709e-10, 5550e-10), 'color': 'blue'},
    'V': {'center': 5479.85e-10, 'range': (4698e-10, 7204e-10), 'color': 'green'},
    # 'R': {'center': 6846.67e-10, 'range': (5233e-10, 9400e-10), 'color': 'red'},
}

plt.figure(figsize=(10,6))
plt.plot(wavelengths*1e10, B_cool, label='T = 5 000 K', color='blue')
plt.plot(wavelengths*1e10, B_cool_synth, label='T = 5 000 K (synth)', color='red')

for name, f in filters.items():
    plt.axvspan(f['range'][0]*1e10, f['range'][1]*1e10, color=f['color'], alpha=0.1, label=f'Filter {name}')
    # plt.axvline(f['center']*1e10, color=f['color'], linestyle='--', label=f'{name} ({f["center"]*1e10:.0f} Å)')

plt.xlabel(r'Wavelength [$\rm \AA$]')
plt.ylabel('Normalised flux density')
# plt.title('Unormowane krzywe Plancka dla 9 000 K, 7 000 K i 5 000 K z filtrami UBVR (Johnson)')
plt.legend(loc='upper right', fontsize=12, ncol=2)
plt.xlim(3000, 10000)
plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_1523.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)

# %%
B_V_cool_synth_flux = -2.5*np.log10(flux_calc(B_cool_synth, wavelengths, 3709e-10, 5550e-10) / flux_calc(B_cool_synth, wavelengths, 4698e-10, 7204e-10))
B_V_cool_flux = -2.5*np.log10(flux_calc(B_cool, wavelengths, 3709e-10, 5550e-10) / flux_calc(B_cool, wavelengths, 4698e-10, 7204e-10))
B_V_cool_synth_centroid = -2.5*np.log10(planck(4384.51e-10, T_cool) / planck(5480e-10, T_cool))

print("Synthetic 5000K B-V (flux): ", B_V_cool_synth_flux)
print("Planck 5000K B-V (flux): ", B_V_cool_flux)
print("Synthetic 5000K B-V (centroid): ", B_V_cool_synth_centroid)
# Out:
# Synthetic 5000K B-V (flux):  0.7360709738041444
# Planck 5000K B-V (flux):  0.48025587279197124
# Synthetic 5000K B-V (centroid):  0.21790331816997754

# %% [markdown]
# #### III Opcja - widma standardów
#
# z bazy: http://svocats.cab.inta-csic.es/miles/index.php
#
# Odpowiedniki temperaturowe dla punktu I i II
#
# Teff_1 → HD198001	* eps Aqr	0776	A1V	0.019	3.77	9470	3.64	0.07
# Teff_2 → HD008829	* 47 Cet	0058	F0V	0.006	5.517	7163	4.15	0.06
# Teff_3 → BD-114126	BD-11 4126	0594	K3V	0.097 E(B-V)	10.4	5000	4.3	0.2
#
# widma w katalogu na google drive, nazwy zaczynają się od miles….
#
# Pytania: 1.5.1 Jak metaliczność wpływa na wskaźnik B-V przy tej samej temperaturze efektywnej?
#
# Dodatkowe linki:
#
# https://userpages.irap.omp.eu/~jleborgne/stelib_web2005/fits_files.html?utm_source=chatgpt.com
#
# https://www.aanda.org/articles/aa/abs/2003/17/aa3079/aa3079.html?utm_source=chatgpt.com
#
# http://svocats.cab.inta-csic.es/miles/index.php?action=search
#
# https://svo2.cab.inta-csic.es/theory/libraries/?utm_source=chatgpt.com
#
#
#
# https://svo2.cab.inta-csic.es/theory/fps3/index.php?id=Generic%2FJohnson.B

# %% [markdown]
# ##### Cool star

# %%
path_to_files = r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/data/miles_spec_BD-114126.txt"

spectrum_data = pd.read_csv(path_to_files, delim_whitespace=True, comment='#', header=None, names=['wavelength', 'flux'])

spectrum_data
# Out:
#       wavelength  flux
# 0         3500.0   0.0
# 1         3500.9   0.0
# 2         3501.8   0.0
# 3         3502.7   0.0
# 4         3503.6   0.0
# ...          ...   ...
# 4362      7425.8   0.0
# 4363      7426.7   0.0
# 4364      7427.6   0.0
# 4365      7428.5   0.0
# 4366      7429.4   0.0
#
# [4367 rows x 2 columns]

# %%
# Stałe fizyczne
h = 6.62607015e-34  #  Planck [J s]
c = 2.99792458e8    # prędkość światła [m/s]
k = 1.380649e-23     # Boltzmann [J/K]

def planck(wavelength, T):
    a = 2.0 * h * c**2
    b = h * c / (wavelength * k * T)
    intensity = a / (wavelength**5 * (np.exp(b) - 1.0))
    return intensity


B_cold = spectrum_data["flux"]

B_cold /= B_cold.max()

filters = {
    # 'U': {'center': 3520.30e-10, 'range': (3010e-10, 4100e-10), 'color': 'violet'},
    'B': {'center': 4384.51e-10, 'range': (3709e-10, 5550e-10), 'color': 'blue'},
    'V': {'center': 5479.85e-10, 'range': (4698e-10, 7204e-10), 'color': 'green'},
    # 'R': {'center': 6846.67e-10, 'range': (5233e-10, 9400e-10), 'color': 'red'},
}

plt.figure(figsize=(10,6))
plt.plot(spectrum_data['wavelength'], B_cold, label='BD114126', color='black')

for name, f in filters.items():
    plt.axvspan(f['range'][0]*1e10, f['range'][1]*1e10, color=f['color'], alpha=0.1, label=f'Filter {name}')
    # plt.axvline(f['center']*1e10, color=f['color'], linestyle='--', label=f'{name} ({f["center"]*1e10:.0f} Å)')

plt.xlabel(r'Wavelength [$\rm \AA$]')
plt.ylabel('Normalised flux density')
# plt.title('Unormowane krzywe Plancka dla 9 000 K, 7 000 K i 5 000 K z filtrami UBVR (Johnson)')
plt.legend(loc='upper right', fontsize=12, ncol=2)
plt.xlim(3500, 7500)
plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_1533.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)

# %%
B_V_cool_flux = -2.5*np.log10(flux_calc(B_cold, spectrum_data['wavelength'], 3709, 5550) / flux_calc(B_cold, spectrum_data['wavelength'], 4698, 7204))

print("Integrator B-V (flux): ", B_V_cool_flux)
# Out:
# Integrator B-V (flux):  0.5958392036983357

# %% [markdown]
# ##### Warm star

# %%
path_to_files = r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/data/miles_spec_HD008829.txt"

spectrum_data = pd.read_csv(path_to_files, delim_whitespace=True, comment='#', header=None, names=['wavelength', 'flux'])

spectrum_data
# Out:
#       wavelength  flux
# 0         3500.0   0.0
# 1         3500.9   0.0
# 2         3501.8   0.0
# 3         3502.7   0.0
# 4         3503.6   0.0
# ...          ...   ...
# 4362      7425.8   0.0
# 4363      7426.7   0.0
# 4364      7427.6   0.0
# 4365      7428.5   0.0
# 4366      7429.4   0.0
#
# [4367 rows x 2 columns]

# %%
# Stałe fizyczne
h = 6.62607015e-34  #  Planck [J s]
c = 2.99792458e8    # prędkość światła [m/s]
k = 1.380649e-23     # Boltzmann [J/K]

def planck(wavelength, T):
    a = 2.0 * h * c**2
    b = h * c / (wavelength * k * T)
    intensity = a / (wavelength**5 * (np.exp(b) - 1.0))
    return intensity


B_cold = spectrum_data["flux"]

B_cold /= B_cold.max()

filters = {
    # 'U': {'center': 3520.30e-10, 'range': (3010e-10, 4100e-10), 'color': 'violet'},
    'B': {'center': 4384.51e-10, 'range': (3709e-10, 5550e-10), 'color': 'blue'},
    'V': {'center': 5479.85e-10, 'range': (4698e-10, 7204e-10), 'color': 'green'},
    # 'R': {'center': 6846.67e-10, 'range': (5233e-10, 9400e-10), 'color': 'red'},
}

plt.figure(figsize=(10,6))
plt.plot(spectrum_data['wavelength'], B_cold, label='BD114126', color='black')

for name, f in filters.items():
    plt.axvspan(f['range'][0]*1e10, f['range'][1]*1e10, color=f['color'], alpha=0.1, label=f'Filter {name}')
    # plt.axvline(f['center']*1e10, color=f['color'], linestyle='--', label=f'{name} ({f["center"]*1e10:.0f} Å)')

plt.xlabel(r'Wavelength [$\rm \AA$]')
plt.ylabel('Normalised flux density')
# plt.title('Unormowane krzywe Plancka dla 9 000 K, 7 000 K i 5 000 K z filtrami UBVR (Johnson)')
plt.legend(loc='upper right', fontsize=12, ncol=2)
plt.xlim(3500, 7500)
plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_1532.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)

# %%
B_V_cool_flux = -2.5*np.log10(flux_calc(B_cold, spectrum_data['wavelength'], 3709, 5550) / flux_calc(B_cold, spectrum_data['wavelength'], 4698, 7204))

print("Integrator B-V (flux): ", B_V_cool_flux)
# Out:
# Integrator B-V (flux):  -0.047353669586548755

# %% [markdown]
# ##### Hot star

# %%
path_to_files = r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/data/miles_spec_HD198001.txt"

spectrum_data = pd.read_csv(path_to_files, delim_whitespace=True, comment='#', header=None, names=['wavelength', 'flux'])

spectrum_data
# Out:
#       wavelength  flux
# 0         3500.0   0.0
# 1         3500.9   0.0
# 2         3501.8   0.0
# 3         3502.7   0.0
# 4         3503.6   0.0
# ...          ...   ...
# 4362      7425.8   0.0
# 4363      7426.7   0.0
# 4364      7427.6   0.0
# 4365      7428.5   0.0
# 4366      7429.4   0.0
#
# [4367 rows x 2 columns]

# %%
# Stałe fizyczne
h = 6.62607015e-34  #  Planck [J s]
c = 2.99792458e8    # prędkość światła [m/s]
k = 1.380649e-23     # Boltzmann [J/K]

def planck(wavelength, T):
    a = 2.0 * h * c**2
    b = h * c / (wavelength * k * T)
    intensity = a / (wavelength**5 * (np.exp(b) - 1.0))
    return intensity


B_cold = spectrum_data["flux"]

B_cold /= B_cold.max()

filters = {
    # 'U': {'center': 3520.30e-10, 'range': (3010e-10, 4100e-10), 'color': 'violet'},
    'B': {'center': 4384.51e-10, 'range': (3709e-10, 5550e-10), 'color': 'blue'},
    'V': {'center': 5479.85e-10, 'range': (4698e-10, 7204e-10), 'color': 'green'},
    # 'R': {'center': 6846.67e-10, 'range': (5233e-10, 9400e-10), 'color': 'red'},
}

plt.figure(figsize=(10,6))
plt.plot(spectrum_data['wavelength'], B_cold, label='BD114126', color='black')

for name, f in filters.items():
    plt.axvspan(f['range'][0]*1e10, f['range'][1]*1e10, color=f['color'], alpha=0.1, label=f'Filter {name}')
    # plt.axvline(f['center']*1e10, color=f['color'], linestyle='--', label=f'{name} ({f["center"]*1e10:.0f} Å)')

plt.xlabel(r'Wavelength [$\rm \AA$]')
plt.ylabel('Normalised flux density')
# plt.title('Unormowane krzywe Plancka dla 9 000 K, 7 000 K i 5 000 K z filtrami UBVR (Johnson)')
plt.legend(loc='upper right', fontsize=12, ncol=2)
plt.xlim(3500, 7500)
plt.ylim(0, 1.05)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(r"/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad_1531.pdf", dpi=600, bbox_inches = 'tight', pad_inches = 0.1)

# %%
B_V_cool_flux = -2.5*np.log10(flux_calc(B_cold, spectrum_data['wavelength'], 3709, 5550) / flux_calc(B_cold, spectrum_data['wavelength'], 4698, 7204))

print("Integrator B-V (flux): ", B_V_cool_flux)
# Out:
# Integrator B-V (flux):  -0.34395890796230366
