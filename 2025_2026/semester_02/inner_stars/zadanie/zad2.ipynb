# %% [markdown]
# # Simple star model

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Simple star model:
# density profile: rho(r) = rho_c * (1 - (r/R))^n
# n = 1

# %% [markdown]
# ## Linear model (n = 1)

# %% [markdown]
# ### Density distribution

# %% [markdown]
# ### Mass distribution

# %%
# after integration: m(r) = rho_c * pi * r^3 (4/3 - r/R)

def mass_func(r, rho_c, R):
    return rho_c * np.pi * r**3 * (4/3 - r/R)

R = 1
rho_c = 1
r = np.linspace(0, R, 100)
m = mass_func(r, rho_c, R)

fig, ax = plt.subplots()
ax.plot(r, m)
ax.set_xlabel('r/R')
ax.set_ylabel('m(r)')
plt.show()

# %% [markdown]
# ### Pressure distribution

# %% [markdown]
# ### Temperature distribution

# %% [markdown]
# ### Central values

# %%
Ms = 2e30 # mass of the star (kg)
Rs = 7e8 # radius of the star (m)
mu = 0.6
G = 6.67430e-11 # gravitational constant (m^3 kg^-1 s^-2)
k_B = 1.380649e-23 # Boltzmann constant (J/K
m_p = 1.6726219e-27 # proton mass (kg)

# %%
# Central density
rho_c = 3 * Ms / (np.pi * Rs**3) # kg/m^3
print("Central density:", rho_c, "kg/m^3")
# Out:
# Central density: 5568.102965314124 kg/m^3

# %%
# Central pressure
P_c = (G * rho_c**2 * Rs**2 * np.pi) * 5/36
print("Central pressure:", P_c, "Pa")
# Out:
# Central pressure: 442418924064238.9 Pa

# %%
# Central temperature
T_c = mu * m_p * G * np.pi * rho_c * (5 * Rs**2 / 36)/ k_B
print("Central temperature:", T_c, "K")
# Out:
# Central temperature: 5775534.521999644 K

# %% [markdown]
# ### Plots

# %%
x = np.arange(0, 1.01, 0.01)
mass = 4*x**3 * (1 - 3*x/4)

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, mass, lw=0.8, color='black')
ax.set_xlabel('r/R; R=1', fontsize=12)
ax.set_ylabel('m(r)/M_central', fontsize=12)

plt.show()

# %%
temperature = 1 + x - 19*x**2/5 + 9*x**3/5

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, temperature, lw=0.8, color='black')
ax.set_xlabel('r/R; R=1', fontsize=12)
ax.set_ylabel('T(r)/T_central', fontsize=12)

plt.show()

# %%
pressure = 1 - 24*x**2/5 + 28*x**3/5 - 9*x**4/5

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, pressure, lw=0.8, color='black')
ax.set_xlabel('r/R; R=1', fontsize=12)
ax.set_ylabel('P(r)/P_central', fontsize=12)

plt.show()

# %%
density = 1 - x

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, density, lw=0.8, color='black')
ax.set_xlabel('r/R; R=1', fontsize=12)
ax.set_ylabel('rho(r)/rho_central', fontsize=12)

plt.show()

# %% [markdown]
# # TBD

# %% [markdown]
# - [ ] Add solar normalized model values (look to the data folder, you have files there)
# - [ ] Place plots at similar window, make models visible on the same plot

# %% [markdown]
# ## Square model (n = 2)

# %%
density = (1 - x)**2

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, density, lw=0.8, color='black')
ax.set_xlabel('r/R; R=1, n=2', fontsize=12)
ax.set_ylabel('rho(r)/rho_central', fontsize=12)

plt.show()

# %%
temperature = (1 / 13) * (13 - 150*x**2 + 350*x**3 - 345*x**4 + 162*x**5 - 30*x**6)

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, temperature, lw=0.8, color='black')
ax.set_xlabel('r/R; R=1, n=2', fontsize=12)
ax.set_ylabel('T(r)/T_central', fontsize=12)

plt.show()

# %%
# mass

# %%
# pressure - czarek do roboty

# %% [markdown]
# ### n = 3

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 1.01, 0.01)

# %%
density = (1 - x)**3

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, density, lw=0.8, color='black')
ax.set_xlabel('r/R; R=1, n=2', fontsize=12)
ax.set_ylabel('rho(r)/rho_central', fontsize=12)

plt.show()

# %%
mass = x**3 * (20 - 45*x + 36*x**2 - 10*x**3)

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, mass, lw=0.8, color='black')
ax.set_xlabel('r/R; R=1, n=3', fontsize=12)
ax.set_ylabel('m(r)/M_central', fontsize=12)
plt.show()

# %%
pressure = (66 - 1400*x**2 + 4900*x**3 - 8085*x**4 + 7644*x**5 - 4270*x**6 + 1320*x**7 - 175*x**8) / 66

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, pressure, lw=0.8, color='black')
ax.set_xlabel('r/R; R=1, n=3', fontsize=12)
ax.set_ylabel('P(r)/P_central', fontsize=12)
plt.show()

# %%
temp = (66 - 1400*x**2 + 4900*x**3 - 8085*x**4 + 7644*x**5 - 4270*x**6 + 1320*x**7 - 175*x**8) / (66 * (1 - x)**3)

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(x, pressure, lw=0.8, color='black')
ax.set_xlabel('r/R; R=1, n=3', fontsize=12)
ax.set_ylabel('P(r)/P_central', fontsize=12)
plt.show()
# Out:
# /tmp/ipykernel_33525/3650138136.py:1: RuntimeWarning: invalid value encountered in divide
#   temp = (66 - 1400*x**2 + 4900*x**3 - 8085*x**4 + 7644*x**5 - 4270*x**6 + 1320*x**7 - 175*x**8) / (66 * (1 - x)**3)

# %% [markdown]
# #### Let's group this up

# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.loadtxt('/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/data/Standard_Solar_Model.dat', comments='#')

m_data   = data[:, 0]
x_data   = data[:, 1]
T_data   = data[:, 2]
rho_data = data[:, 3]
P_data   = data[:, 4]

T_data_norm   = T_data / T_data[0]
rho_data_norm = rho_data / rho_data[0]
P_data_norm   = P_data / P_data[0]

x = np.linspace(0, 1, 1000)

# --- Model dla n = 1 ---
rho_1 = 1 - x
m_1 = (4 - 3*x) * x**3
P_1 = 1 - (24/5)*x**2 + (28/5)*x**3 - (9/5)*x**4
T_1 = 1 + x - (19/5)*x**2 + (9/5)*x**3

# --- Model dla n = 2 ---
rho_2 = (1 - x)**2
m_2 = (10 - 15*x + 6*x**2) * x**3
P_2 = 1 - (150/13)*x**2 + (350/13)*x**3 - (345/13)*x**4 + (162/13)*x**5 - (30/13)*x**6
T_2 = 1 + 2*x - (111/13)*x**2 + (102/13)*x**3 - (30/13)*x**4

# --- Model dla n = 3 ---
rho_3 = (1 - x)**3
m_3 = (20 - 45*x + 36*x**2 - 10*x**3) * x**3
P_3 = 1 - (700/33)*x**2 + (2450/33)*x**3 - (245/2)*x**4 + (1274/11)*x**5 - (2135/33)*x**6 + 20*x**7 - (175/66)*x**8
T_3 = 1 + 3*x - (502/33)*x**2 + (680/33)*x**3 - (265/22)*x**4 + (175/66)*x**5

fig, axs = plt.subplots(2, 2, figsize=(8, 8), sharex=True)

axs[0, 0].plot(x, rho_1, "#972828")
axs[0, 0].plot(x, rho_2, "#61BD45")
axs[0, 0].plot(x, rho_3, "#B13ECE")
axs[0, 0].plot(x_data, rho_data_norm, 'k')
axs[0, 0].set_ylabel(r'$\rm \rho(r) / \rho_c$')

axs[0, 1].plot(x, m_1, "#972828") 
axs[0, 1].plot(x, m_2, "#61BD45")
axs[0, 1].plot(x, m_3, "#B13ECE")
axs[0, 1].plot(x_data, m_data, 'k')
axs[0, 1].set_ylabel(r'$\rm m(r) / M_c$')

axs[1, 0].plot(x, T_1, "#972828")
axs[1, 0].plot(x, T_2, "#61BD45")
axs[1, 0].plot(x, T_3, "#B13ECE")
axs[1, 0].plot(x_data, T_data_norm, 'k')
axs[1, 0].set_ylabel(r'$\rm T(r) / T_c$')
axs[1, 0].set_xlabel(r'$\rm r/R$')

axs[1, 1].plot(x, P_1, "#972828", label='n = 1')
axs[1, 1].plot(x, P_2, "#61BD45", label='n = 2')
axs[1, 1].plot(x, P_3, "#B13ECE", label='n = 3')
axs[1, 1].plot(x_data, P_data_norm, 'k', label='Standard Solar Model')
axs[1, 1].set_xlabel(r'$\rm r/R$')
axs[1, 1].set_ylabel(r'$\rm P(r) / P_c$')
axs[1, 1].legend(fontsize=10)

plt.tight_layout()
fig.savefig('/media/olehryz/Elements/progs/univ_codes/2025_2026/semester_02/inner_stars/figures/zad2_plot.pdf', dpi=600, bbox_inches='tight')
