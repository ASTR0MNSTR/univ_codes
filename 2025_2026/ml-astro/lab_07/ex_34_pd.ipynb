# %%
import numpy as np
from scipy.special import gamma

def calculate_pD(D):
    """
    Calculate pD = (π^(D/2)) / (2^(D-1) * Γ(D/2))
    
    Parameters:
    D (int or float): Dimensionality
    
    Returns:
    float: The calculated pD value
    """
    numerator = np.pi ** (D / 2)
    denominator = (2 ** (D - 1)) * gamma(D / 2)
    pD = numerator / denominator
    return pD

# Example usage
D = [10, 100, 1000, 10000]
for D in D:
    result = calculate_pD(D)
    print(f"pD for D={D}: {result}")
# Out:
# pD for D=10: 0.024903945701927197
# pD for D=100: 1.8681820538375917e-68
# pD for D=1000: 0.0
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[1], line 22
#      20 D = [10, 100, 1000, 10000]
#      21 for D in D:
# ---> 22     result = calculate_pD(D)
#      23     print(f"pD for D={D}: {result}")
#
# Cell In[1], line 14, in calculate_pD(D)
#       4 def calculate_pD(D):
#       5     """
#       6     Calculate pD = (π^(D/2)) / (2^(D-1) * Γ(D/2))
#       7
#    (...)
#      12     float: The calculated pD value
#      13     """
# ---> 14     numerator = np.pi ** (D / 2)
#      15     denominator = (2 ** (D - 1)) * gamma(D / 2)
#      16     pD = numerator / denominator
#
# OverflowError: (34, 'Numerical result out of range')
