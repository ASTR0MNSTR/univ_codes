# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('period_scan.log', comment='#', delim_whitespace=True, names=['period', 'rms', 'chi2', 'iter', 'dark_area_percent'], header=None)

df
# Out:
#         period       rms      chi2  iter  dark_area_percent
# 0    23.000870  0.017266  0.485359    50                0.6
# 1    23.003010  0.017659  0.507667    50                0.3
# 2    23.007708  0.017768  0.513942    50                0.3
# 3    23.010197  0.017449  0.495666    50                3.7
# 4    23.013276  0.016949  0.467657    50                1.0
# ..         ...       ...       ...   ...                ...
# 141  23.481720  0.017901  0.521708    50                1.9
# 142  23.486123  0.018042  0.529937    50                1.5
# 143  23.489509  0.018316  0.546148    50                0.2
# 144  23.492715  0.017171  0.479990    50                0.0
# 145  23.496044  0.018732  0.571259    50                2.2
#
# [146 rows x 5 columns]

# %%
best_period = df.loc[df['rms'].idxmin()]['period']
print(f"Best period with minimum RMS: {best_period}")

min_rms = 1.05*df['rms'].min()
# Out:
# Best period with minimum RMS: 23.184712

# %%
fig, ax = plt.subplots(figsize=(10, 6))

ax.plot(df['period'], df['rms'], marker='o', linestyle='-', color='b')
ax.set_xlabel('Period')
ax.set_ylabel('RMS')
ax.set_title('RMS vs Period Scan')
ax.grid(True)
ax.axhline(y=min_rms, color='r', linestyle='--', label='1.10 * Min RMS')
ax.legend()
plt.show()
