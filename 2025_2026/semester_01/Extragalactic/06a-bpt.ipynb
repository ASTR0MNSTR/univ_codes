# %% [markdown]
# ## Aim of this class is to get familiar with estimating ``activity'' of galaxies

# %% [markdown]
# Some questions to answer:
# - how can we assess the ``activity'' of a galaxy?
# - what information about a galaxy would we need?
# - how confident can we be with our estimations?

# %% [markdown]
# do **NOT** copy the catalogues (they'll eat up your quota), use them directly via:

# %%
# szuflada_path = '/home/SZUFLADA/PN/extragalactic_classes/gama_dr4/'
szuflada_path = '/media/olehryz/Elements/databases/GAMA_DR4/fits/'

lines_file = szuflada_path + 'GaussFitComplexv05.fits'

# %% [markdown]
# some imports:

# %%
import pandas as pd
pd.options.mode.copy_on_write = True

from astropy.io import fits
from astropy.table import Table

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import astropy.units as u

# %% [markdown]
# ### TASK: explore the ``Baldwin, Phillips & Terlevich'' (BPT) diagram, based on GAMA galaxies

# %% [markdown]
# TODOs:
# - create a BPT diagram for GAMA galaxies
# - mark on the diagram different classes of galaxies
# - mark division lines between the classes

# %% [markdown]
# some usefull pointers:
# - Baldwin, Phillips & Terlevich 1981
# - Kewley+2001
# - Kauffmann+2003
# - SpecLineSFR DMU from GAMA DR4
# - some other papers about BPT diagram for GAMA galaxies ;)

# %%
with fits.open(lines_file) as hdul:
   data = hdul[1].data

data
# Out:
# FITS_rec([('1030206976962881536', 454340,  3.9914443, 0.06175309, -4.4398337e-05, 7.61742558e-05, 1.2781872, 1.2616848, 0., 3,   0, 0, 0, -5.9470057, -12.633695 , -6.5769744 , 6924.39260834,   0.       , -0.       , -135.82507 , -0.        , 1.2306969, -0.        ,   0.      ,  -0.      ,   0.        , -0.        , -6.3441426e-01,  2.5299299e-01,   -131.63239 , -0.0000000e+00,  1.8171741e+01, -0.0000000e+00, -2.8897442e+01,  1.1523780e+01, -5.1771584e+00,  2.0661471e+00, 2, -9.9999000e+04, -9.999900e+04, -99999.   , -9.9999000e+04, -99999.     , -99999., -99999.    , -99999.    , -9.9999000e+04, -9.9999000e+04, 0,  -0.17907165,  0.40531808,  2.1859448 , 0.1414992 , 7.2701273 , 4.6304045 ,  -3.2633135,   7.673171 ,  -0.58551335,  1.3767728 ,   0.8590738,  0.4576994, 69.12808 , 4.474756  , 7.3066425 ,  4.6536613,   15.733969,  13.064967,  2.8251390e+00,  2.3463128 , 0, 0, -1.3204446e+00,  3.5701420e+00, -6.4149187e-03,  2.8555398e-03,  1.0935454e+00,  1.1975232e+00, 0., 2,   0,  1, 100, -3.8844779e+00,  3.5150108e+00,  5.5680003e+00,  9164.13785946,  4.2888055e+00,  2.3671911e+00,  6.1136546e+00, -0.0000000e+00,  1.4593022e+00, -0.0000000e+00,  1.5688142e+01,  8.6590147e+00, -8.2629995e+00,  2.2171028e+01, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.999900e+04, -9.999900e+04, -9.99990e+04, -9.999900e+04, -9.9999000e+04, 0,  6.8112650e+00,  3.1607120e+00, -1.2227309e+01, -0.0000000e+00,  6.9177910e+01,  1.2896744e+01,   1181.096  ,    590.6548, -6.8101794e+02,  1.9870785e+03, 1,  3.5853827e-01,  1.2667887e+00, -1.6205515e+01,  9.7380298e-01,  6.8940477e+00,  2.8812468e+00,  6.1958337e+00,  2.2043758e+01, -3.6474526e+00,  1.6822901e+01,  5.3709717e+00,  1.6561068e+00,  3.3198139e+01,  1.9949040e+00,  6.9111676e+00,  2.8884017e+00,  9.3045250e+01,  4.8324772e+01, -4.3454430e+01,  1.0369449e+02, 0, 0),
-9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, 1., 0,   0,  0,   0, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, 11230.45990978, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.999900e+04, -9.999900e+04, -9.99990e+04, -9.999900e+04, -9.9999000e+04, 0, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -99999.     , -99999.    , -9.9999000e+04, -9.9999000e+04, 0, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, 0, 0),
#           ('W153051',     -1,  9.169501 , 1.1587807 ,  5.0010785e-05, 6.20259554e-04, 0.8888213, 0.8726139, 0., 0, 201, 0, 0,  0.9573584,  -6.47283  , -0.67541444, 6434.47873277, 113.18567  , 18.155743 , -126.41368 ,  0.65859634, 3.2071986,  0.6409668 , 909.9284  , 233.1821  ,  76.52915   , 21.879423  , -1.2140528e+01, -0.0000000e+00,   -122.319145, -0.0000000e+00,  1.6899456e+01, -0.0000000e+00, -5.1428070e+02,  0.0000000e+00, -4.3252399e+01,  5.4813113e+00, 3, -9.9999000e+04, -9.999900e+04, -99999.   , -9.9999000e+04, -99999.     , -99999., -99999.    , -99999.    , -9.9999000e+04, -9.9999000e+04, 0, 138.8189    , 12.877487  ,  0.37141377, 0.00074176, 2.518698  , 0.11789912, 876.42474  ,  91.06561  ,  73.66037   , 12.051201  , 435.90915  , 22.16889  , 62.57727 , 0.12497459, 2.5265486 ,  0.1182666, 2760.6643  , 190.81633 ,  2.3194528e+02, 33.415237  , 0, 0,  1.2003613e+01,  2.8643281e+00,  2.4768277e-03,  1.4281768e-03,  1.7776308e+00,  1.7993778e+00, 0., 0, 201,  0,   0, -6.0310507e+00, -5.8166118e+00, -2.3925381e+00,  8515.75777057,  3.5523590e+02,  1.9666801e+01,  2.8042948e-01,  1.2660995e-01,  2.1718094e+00,  1.4549476e-01,  1.9338754e+03,  1.6806932e+02,  1.2415299e+02,  3.1527760e+01, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.9999000e+04, -9.999900e+04, -9.999900e+04, -9.99990e+04, -9.999900e+04, -9.9999000e+04, 0,  1.5698774e+01,  8.4158030e+00,  3.7626309e+00,  1.2341452e+01,  1.9092516e+01,  1.1926847e+01,    751.30945,    618.4586,  4.8198738e+01,  4.1307045e+01, 0, -1.9591436e+01, -0.0000000e+00, -1.7468014e+01,  6.8897688e-01,  1.9857293e+00,  1.2886975e+00, -9.7516090e+01,  6.3285934e+01, -6.2834516e+00,  4.3466406e+00,  4.1461399e+01,  1.9649513e+01,  2.8440239e+01,  1.1217456e+00,  1.9841504e+00,  1.2876729e+00,  2.0620941e+02,  1.6571046e+02,  1.3161979e+01,  1.1028347e+01, 1, 0)],
#          dtype=(numpy.record, [('SPECID', 'S33'), ('CATAID', '>i4'), ('HB_CONT', '>f4'), ('HB_CONT_ERR', '>f4'), ('HB_GRAD', '>f4'), ('HB_GRAD_ERR', '>f4'), ('HB_REDCHI_EMB', '>f4'), ('HB_REDCHI_EMABS', '>f4'), ('HB_FITFAIL', '>f4'), ('HB_NPEG', '>i2'), ('HB_MODSEL_EM_LINE', '>i2'), ('HB_MODSEL_EMB_EM', '>i2'), ('HB_MODSEL_NABS_N', '>i2'), ('HB_BF', '>f4'), ('HB_DELBIC', '>f4'), ('HB_DELAIC', '>f4'), ('HB_CEN', '>f8'), ('AMP_HB', '>f4'), ('AMP_HB_ERR', '>f4'), ('POS_HB', '>f4'), ('POS_HB_ERR', '>f4'), ('SIG_HB', '>f4'), ('SIG_HB_ERR', '>f4'), ('HB_FLUX', '>f4'), ('HB_FLUX_ERR', '>f4'), ('HB_EW', '>f4'), ('HB_EW_ERR', '>f4'), ('AMP_HB_ABS', '>f4'), ('AMP_HB_ABS_ERR', '>f4'), ('POS_HB_ABS', '>f4'), ('POS_HB_ABS_ERR', '>f4'), ('SIG_HB_ABS', '>f4'), ('SIG_HB_ABS_ERR', '>f4'), ('HB_ABS_FLUX', '>f4'), ('HB_ABS_FLUX_ERR', '>f4'), ('HB_ABS_EW', '>f4'), ('HB_ABS_EW_ERR', '>f4'), ('HB_ABS_NPEG', '>i2'), ('AMP_HB_B', '>f4'), ('AMP_HB_B_ERR', '>f4'), ('POS_HB_B', '>f4'), ('POS_HB_B_ERR', '>f4'), ('SIG_HB_B', '>f4'), ('SIG_HB_B_ERR', '>f4'), ('HB_B_FLUX', '>f4'), ('HB_B_FLUX_ERR', '>f4'), ('HB_B_EW', '>f4'), ('HB_B_EW_ERR', '>f4'), ('HB_B_NPEG', '>i2'), ('AMP_OIIIB', '>f4'), ('AMP_OIIIB_ERR', '>f4'), ('POS_OIIIB', '>f4'), ('POS_OIIIB_ERR', '>f4'), ('SIG_OIIIB', '>f4'), ('SIG_OIIIB_ERR', '>f4'), ('OIIIB_FLUX', '>f4'), ('OIIIB_FLUX_ERR', '>f4'), ('OIIIB_EW', '>f4'), ('OIIIB_EW_ERR', '>f4'), ('AMP_OIIIR', '>f4'), ('AMP_OIIIR_ERR', '>f4'), ('POS_OIIIR', '>f4'), ('POS_OIIIR_ERR', '>f4'), ('SIG_OIIIR', '>f4'), ('SIG_OIIIR_ERR', '>f4'), ('OIIIR_FLUX', '>f4'), ('OIIIR_FLUX_ERR', '>f4'), ('OIIIR_EW', '>f4'), ('OIIIR_EW_ERR', '>f4'), ('OIIIR_NPEG', '>i2'), ('OIIIB_NPEG', '>i2'), ('HA_CONT', '>f4'), ('HA_CONT_ERR', '>f4'), ('HA_GRAD', '>f4'), ('HA_GRAD_ERR', '>f4'), ('HA_REDCHI_EMB', '>f4'), ('HA_REDCHI_EMABS', '>f4'), ('HA_FITFAIL', '>f4'), ('HA_NPEG', '>i2'), ('HA_MODSEL_EM_LINE', '>i2'), ('HA_MODSEL_EMB_EM', '>i2'), ('HA_MODSEL_NABS_N', '>i2'), ('HA_BF', '>f4'), ('HA_DELBIC', '>f4'), ('HA_DELAIC', '>f4'), ('HA_CEN', '>f8'), ('AMP_HA', '>f4'), ('AMP_HA_ERR', '>f4'), ('POS_HA', '>f4'), ('POS_HA_ERR', '>f4'), ('SIG_HA', '>f4'), ('SIG_HA_ERR', '>f4'), ('HA_FLUX', '>f4'), ('HA_FLUX_ERR', '>f4'), ('HA_EW', '>f4'), ('HA_EW_ERR', '>f4'), ('AMP_HA_ABS', '>f4'), ('AMP_HA_ABS_ERR', '>f4'), ('POS_HA_ABS', '>f4'), ('POS_HA_ABS_ERR', '>f4'), ('SIG_HA_ABS', '>f4'), ('SIG_HA_ABS_ERR', '>f4'), ('HA_ABS_FLUX', '>f4'), ('HA_ABS_FLUX_ERR', '>f4'), ('HA_ABS_EW', '>f4'), ('HA_ABS_EW_ERR', '>f4'), ('HA_ABS_NPEG', '>i2'), ('AMP_HA_B', '>f4'), ('AMP_HA_B_ERR', '>f4'), ('POS_HA_B', '>f4'), ('POS_HA_B_ERR', '>f4'), ('SIG_HA_B', '>f4'), ('SIG_HA_B_ERR', '>f4'), ('HA_B_FLUX', '>f4'), ('HA_B_FLUX_ERR', '>f4'), ('HA_B_EW', '>f4'), ('HA_B_EW_ERR', '>f4'), ('HA_B_NPEG', '>i2'), ('AMP_NIIB', '>f4'), ('AMP_NIIB_ERR', '>f4'), ('POS_NIIB', '>f4'), ('POS_NIIB_ERR', '>f4'), ('SIG_NIIB', '>f4'), ('SIG_NIIB_ERR', '>f4'), ('NIIB_FLUX', '>f4'), ('NIIB_FLUX_ERR', '>f4'), ('NIIB_EW', '>f4'), ('NIIB_EW_ERR', '>f4'), ('AMP_NIIR', '>f4'), ('AMP_NIIR_ERR', '>f4'), ('POS_NIIR', '>f4'), ('POS_NIIR_ERR', '>f4'), ('SIG_NIIR', '>f4'), ('SIG_NIIR_ERR', '>f4'), ('NIIR_FLUX', '>f4'), ('NIIR_FLUX_ERR', '>f4'), ('NIIR_EW', '>f4'), ('NIIR_EW_ERR', '>f4'), ('NIIB_NPEG', '>i2'), ('NIIR_NPEG', '>i2')]))

# %%
table = Table(data)

lines = table.to_pandas()

lines.head()
# Out:
#                               SPECID  CATAID    HB_CONT  HB_CONT_ERR  \
# 0  1030206976962881536                454340   3.991444     0.061753
# 1  1030207251840788480                478246  27.101358     0.134811
# 2  1030207801596602368                478249  39.710850     0.244997
# 3  1030208626230323200                454298  30.505415     0.220010
# 4  1030217972079159296                457151  45.830002     0.229451
#
#     HB_GRAD  HB_GRAD_ERR  HB_REDCHI_EMB  HB_REDCHI_EMABS  HB_FITFAIL  HB_NPEG  \
# 0 -0.000044     0.000076       1.278187         1.261685         0.0        3
# 1  0.000009     0.000033       1.136868         1.106717         0.0        0
# 2 -0.000081     0.000041       1.232322         1.176592         0.0        1
# 3 -0.000257     0.000046       1.352126         1.281670         0.0        0
# 4 -0.000068     0.000035       1.174065         1.065116         0.0        0
#
#    ...   POS_NIIR  POS_NIIR_ERR  SIG_NIIR  SIG_NIIR_ERR   NIIR_FLUX  \
# 0  ...  33.198139      1.994904  6.911168      2.888402   93.045250
# 1  ...  22.995220      0.434402  2.618714      0.419719   69.508110
# 2  ...  23.285004      1.278312  3.840015      1.322465   49.923748
# 3  ...  24.007812      0.160095  3.050972      0.165903  245.131943
# 4  ...  22.759569      0.105857  1.569237      0.108898  165.324478
#
#    NIIR_FLUX_ERR    NIIR_EW  NIIR_EW_ERR  NIIB_NPEG  NIIR_NPEG
# 0      48.324772 -43.454430   103.694489          0          0
# 1      15.079922   1.997449     0.434323          0          0
# 2      23.125069   0.832827     0.385787          0          0
# 3      18.146864   6.362538     0.472219          0          0
# 4      15.793898   4.141389     0.396054          0          0
#
# [5 rows x 140 columns]

# %% [markdown]
# ### Classic BPT diagram requirements:
# - S/N of ALL LINES (OIII5007, NII6563, HA, HB) > 3
# - Theoretical lines are taken from the papers of Kauffmann and Kewley (or from Ryzhov+2025)

# %%
lines_bpt = lines[
    (lines['NIIR_FLUX'] > 0) & (lines['NIIR_FLUX'] > 3*lines['NIIR_FLUX_ERR']) &
    (lines['HA_FLUX'] > 0) & (lines['HA_FLUX'] > 3*lines['HA_FLUX_ERR']) &
    (lines['OIIIR_FLUX'] > 0) & (lines['OIIIR_FLUX'] > 3*lines['OIIIR_FLUX_ERR']) &
    (lines['HB_FLUX'] > 0) & (lines['HB_FLUX'] > 3*lines['HB_FLUX_ERR'])
]

lines_bpt.shape
# Out:
# (51782, 140)

# %%
fig, ax = plt.subplots(figsize=(8, 8))

agns = lines_bpt[
    (np.log10(lines_bpt['OIIIR_FLUX']/lines_bpt['HB_FLUX']) >
     (0.61/(np.log10(lines_bpt['NIIR_FLUX']/lines_bpt['HA_FLUX']) - 0.47)) + 1.19) | 
     (np.log10(lines_bpt['NIIR_FLUX']/lines_bpt['HA_FLUX']) > 0.47)
]

sfrs = lines_bpt[
    (np.log10(lines_bpt['OIIIR_FLUX']/lines_bpt['HB_FLUX']) < 
     (0.61/(np.log10(lines_bpt['NIIR_FLUX']/lines_bpt['HA_FLUX']) - 0.05)) + 1.3) &
     (np.log10(lines_bpt['NIIR_FLUX']/lines_bpt['HA_FLUX']) < 0.05)
]

uncls = lines_bpt.drop(agns.index).drop(sfrs.index)

ax.scatter(np.log10(agns['NIIR_FLUX']/agns['HA_FLUX']),
           np.log10(agns['OIIIR_FLUX']/agns['HB_FLUX']),
           s=1, alpha=0.5, color='red', label='AGN')

ax.scatter(np.log10(sfrs['NIIR_FLUX']/sfrs['HA_FLUX']),
           np.log10(sfrs['OIIIR_FLUX']/sfrs['HB_FLUX']),
           s=1, alpha=0.5, color='blue', label='Star-Forming')

ax.scatter(np.log10(uncls['NIIR_FLUX']/uncls['HA_FLUX']),
           np.log10(uncls['OIIIR_FLUX']/uncls['HB_FLUX']),
           s=1, alpha=0.5, color='green', label='Composite')

ax.set_xlabel(r'$\log \mathrm{([NII]6584\AA/H\alpha)}$')
ax.set_ylabel(r'$\log{\mathrm{([OIII]5007\AA/H\beta)}}$')
ax.set_yticks(np.arange(-1.5, 2.1, 0.5))
ax.set_xticks(np.arange(-2, 1.2, 0.5))
ax.set_xlim(-2.5, 1.5)
ax.set_ylim(-2.0, 2.0)
X_1 = np.arange(-4, 0.4, 0.01)
X_111 = np.arange(-4, 0, 0.01)
X_11 = np.arange(-0.2, 1.5, 0.01)
ax.plot(X_1, (0.61/(X_1 - 0.47)) + 1.19,
                      c='grey', linewidth=1, label='Kewley+01')  # Kewley, 2001
ax.plot(X_111, (0.61/(X_111 - 0.05)) + 1.3,
                      c='grey', linestyle='dashed', linewidth=1, label='Kauffman+03')  # Kauffman, 2003
# ax.plot(X_11, 1.01*X_11 + 0.48, c='grey', linestyle='dotted', linewidth=1, label='Stasinska+06')
ax.text(-1.5, 1.2, 'Active Galactic Nuclei')
ax.text(0, -1, 'Composite', ha='center', va='center', rotation = -45, 
         rotation_mode = 'anchor', 
         transform_rotates_text = True)
ax.text(-1.8, 0.1, 'Star-Forming Galaxies')
# ax.text(1.0, -0.5, 'Low-Ionization (Nuclear) Emission', rotation = 90, 
#          rotation_mode = 'anchor', 
#          transform_rotates_text = True)
ax.set_box_aspect(1)
ax.legend()
