# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path_to_template = r"D:\progs\fuzzy-chainsaw\2024_2025\Spectroscopy\stars_05\DATA\template.txt"

temp = pd.read_csv(path_to_template, sep=r'\s+', header=None, names=['REF', 'NAME'])

# temp

ref_name_dict = dict(zip(temp['REF'], temp['NAME']))

ref_name_dict
# Out:
# {'A': '32Vul_K5III',
#  'B': 'HD116842_A5V',
#  'C': 'HD120315_B3V',
#  'D': 'HD122408_A3V',
#  'E': 'HD130109_A0III',
#  'F': 'HD137391_F0IV',
#  'G': 'HD142574_M0',
#  'H': 'HD144206_B9IV',
#  'I': 'HD145675_K0V',
#  'J': 'HD148783_M6III',
#  'K': 'HD153751_G5III',
#  'L': 'HD154143_M3III',
#  'M': 'HD158899_K3.5III',
#  'N': 'HD160269_G0V',
#  'O': 'HD188001_O8I',
#  'P': 'HD188209_O9.5Iab',
#  'Q': 'HD196610_M6III',
#  'R': 'HD196755_G2IV',
#  'S': 'HD196867_B9IV',
#  'T': 'HD198550_K4V',
#  'U': 'HD217143_G9III',
#  'V': 'HD223486_F0V',
#  'W': 'HD31767_K2IIb',
#  'X': 'HD4758_A9III',
#  'Y': 'HD6301_F7IV',
#  'Z': 'HD6680_F3IV',
#  'AA': 'HD886_B2IV',
#  'AB': 'SF10_G6',
#  'AC': 'SF11_F5',
#  'AD': 'SF12_G5',
#  'AE': 'SF13_F6',
#  'AF': 'SF16_K3',
#  'AG': 'SF18_G0',
#  'AH': 'SF21_F8',
#  'AI': 'SF24_G4',
#  'AJ': 'SF25_G3',
#  'AK': 'SF27_F7',
#  'AL': 'SF28_F8',
#  'AM': 'SF29_G4',
#  'AN': 'SF4_G9',
#  'AO': 'SF7_F7',
#  'AP': 'XiHer_G8III'}

# %%
path_to_res = r"D:\progs\fuzzy-chainsaw\2024_2025\Spectroscopy\stars_05\DATA\cros_1.txt"
res = pd.read_csv(path_to_res, sep="\s+", header=None, names=["OBJECT", "IMAGE", "REF", "HJD", "AP", "CODES", "SHIFT", "HGHT", "FWHM", "TDR", "VOBS", "VREL", "VHELIO", "VERR"])
res
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ryzho\AppData\Local\Temp\ipykernel_1452\959220178.py:2: SyntaxWarning: invalid escape sequence '\s'
#   res = pd.read_csv(path_to_res, sep="\s+", header=None, names=["OBJECT", "IMAGE", "REF", "HJD", "AP", "CODES", "SHIFT", "HGHT", "FWHM", "TDR", "VOBS", "VREL", "VHELIO", "VERR"])
#    OBJECT       IMAGE REF    HJD  AP    CODES     SHIFT  HGHT     FWHM  \
# 0   star1  star1.fits   A  INDEF   1  BNS/gau   594.333  0.37  1195.38
# 1   star1  star1.fits   B  INDEF   1  BNS/gau     2.956  0.91  1434.40
# 2   star1  star1.fits   C  INDEF   1  BNS/gau     1.844  0.69  1611.62
# 3   star1  star1.fits   D  INDEF   1  BNS/gau    -0.000  0.99  1479.62
# 4   star1  star1.fits   E  INDEF   1  BNS/gau     0.583  0.95  1680.91
# 5   star1  star1.fits   F  INDEF   1  BNS/gau     2.868  0.82  1154.53
# 6   star1  star1.fits   G  INDEF   1  BNS/gau   268.588  0.47   182.28
# ...

# %%
positions = np.arange(len(res))

# Plot
plt.figure(figsize=(16, 10))
plt.bar(positions, res['HGHT'], color='mediumseagreen')

# X-axis with REF names

tick_names = [ref_name_dict[key] for key in res['REF']]
plt.xticks(positions, tick_names, rotation=90, ha='center')  # Rotate if names are long
plt.xlabel('REF')
plt.ylabel('HGHT')
plt.title('star1')

plt.tight_layout()
plt.show()

# %%
path_to_res = r"D:\progs\fuzzy-chainsaw\2024_2025\Spectroscopy\stars_05\DATA\cros_2.txt"
res = pd.read_csv(path_to_res, sep="\s+", header=None, names=["OBJECT", "IMAGE", "REF", "HJD", "AP", "CODES", "SHIFT", "HGHT", "FWHM", "TDR", "VOBS", "VREL", "VHELIO", "VERR"])
res
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ryzho\AppData\Local\Temp\ipykernel_1452\168277203.py:2: SyntaxWarning: invalid escape sequence '\s'
#   res = pd.read_csv(path_to_res, sep="\s+", header=None, names=["OBJECT", "IMAGE", "REF", "HJD", "AP", "CODES", "SHIFT", "HGHT", "FWHM", "TDR", "VOBS", "VREL", "VHELIO", "VERR"])
#    OBJECT       IMAGE REF    HJD  AP    CODES     SHIFT  HGHT     FWHM  \
# 0   star2  star2.fits   A  INDEF   1  BNS/gau   586.474  0.25  1024.68
# 1   star2  star2.fits   B  INDEF   1  BNS/gau    -1.384  0.56  1617.18
# 2   star2  star2.fits   C  INDEF   1  BNS/gau    -2.534  0.66  1099.51
# 3   star2  star2.fits   D  INDEF   1  BNS/gau    -4.058  0.51  1582.25
# 4   star2  star2.fits   E  INDEF   1  BNS/gau    -3.925  0.54  1657.71
# 5   star2  star2.fits   F  INDEF   1  BNS/gau    -1.015  0.45  1266.51
# 6   star2  star2.fits   G  INDEF   1  BNS/gau   666.426  0.23  2961.85
# ...

# %%
positions = np.arange(len(res))

# Plot
plt.figure(figsize=(16, 10))
plt.bar(positions, res['HGHT'], color='mediumvioletred')

# X-axis with REF names

tick_names = [ref_name_dict[key] for key in res['REF']]
plt.xticks(positions, tick_names, rotation=90, ha='center')  # Rotate if names are long
plt.xlabel('REF')
plt.ylabel('HGHT')
plt.title('star2')

plt.tight_layout()
plt.show()

# %%
path_to_res = r"D:\progs\fuzzy-chainsaw\2024_2025\Spectroscopy\stars_05\DATA\cros_3.txt"
res = pd.read_csv(path_to_res, sep="\s+", header=None, names=["OBJECT", "IMAGE", "REF", "HJD", "AP", "CODES", "SHIFT", "HGHT", "FWHM", "TDR", "VOBS", "VREL", "VHELIO", "VERR"])
res
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ryzho\AppData\Local\Temp\ipykernel_1452\2283104493.py:2: SyntaxWarning: invalid escape sequence '\s'
#   res = pd.read_csv(path_to_res, sep="\s+", header=None, names=["OBJECT", "IMAGE", "REF", "HJD", "AP", "CODES", "SHIFT", "HGHT", "FWHM", "TDR", "VOBS", "VREL", "VHELIO", "VERR"])
#    OBJECT       IMAGE REF    HJD  AP    CODES     SHIFT  HGHT     FWHM  \
# 0   star3  star3.fits   A  INDEF   1  BNS/gau     0.604  0.77   709.02
# 1   star3  star3.fits   B  INDEF   1  BNS/gau     2.320  0.42   701.74
# 2   star3  star3.fits   C  INDEF   1  BNS/gau  -594.910  0.40  1783.56
# 3   star3  star3.fits   D  INDEF   1  BNS/gau    -0.366  0.42   868.09
# 4   star3  star3.fits   E  INDEF   1  BNS/gau  -593.730  0.39  1361.86
# 5   star3  star3.fits   F  INDEF   1  BNS/gau     2.181  0.61   606.18
# 6   star3  star3.fits   G  INDEF   1  BNS/gau     1.461  0.62  1018.09
# ...

# %%
positions = np.arange(len(res))

# Plot
plt.figure(figsize=(16, 10))
plt.bar(positions, res['HGHT'], color='slateblue')

# X-axis with REF names

tick_names = [ref_name_dict[key] for key in res['REF']]
plt.xticks(positions, tick_names, rotation=90, ha='center')  # Rotate if names are long
plt.xlabel('REF')
plt.ylabel('HGHT')
plt.title('star2')

plt.tight_layout()
plt.show()

# %%
path_to_res = r"D:\progs\fuzzy-chainsaw\2024_2025\Spectroscopy\stars_05\DATA\cros_4.txt"
res = pd.read_csv(path_to_res, sep="\s+", header=None, names=["OBJECT", "IMAGE", "REF", "HJD", "AP", "CODES", "SHIFT", "HGHT", "FWHM", "TDR", "VOBS", "VREL", "VHELIO", "VERR"])
res
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ryzho\AppData\Local\Temp\ipykernel_1452\3704272694.py:2: SyntaxWarning: invalid escape sequence '\s'
#   res = pd.read_csv(path_to_res, sep="\s+", header=None, names=["OBJECT", "IMAGE", "REF", "HJD", "AP", "CODES", "SHIFT", "HGHT", "FWHM", "TDR", "VOBS", "VREL", "VHELIO", "VERR"])
#    OBJECT       IMAGE REF    HJD  AP    CODES    SHIFT   HGHT     FWHM  \
# 0   star4  star4.fits   A  INDEF   1  BNS/gau    0.401   0.33   506.21
# 1   star4  star4.fits   B  INDEF   1  BNS/gau    1.549   0.74  1133.99
# 2   star4  star4.fits   C  INDEF   1  BNS/gau    0.230   0.52  1587.26
# 3   star4  star4.fits   D  INDEF   1  BNS/gau   -1.188   0.61  1137.22
# 4   star4  star4.fits   E  INDEF   1  BNS/gau   -0.733   0.56  1403.78
# 5   star4  star4.fits   F  INDEF   1  BNS/gau    1.618   0.75   878.54
# 6   star4  star4.fits   G  INDEF   1  BNS/gau  694.914   0.19  2090.98
# ...

# %%
positions = np.arange(len(res))

# Plot
plt.figure(figsize=(16, 10))
plt.bar(positions, res['HGHT'], color='brown')

# X-axis with REF names

tick_names = [ref_name_dict[key] for key in res['REF']]
plt.xticks(positions, tick_names, rotation=90, ha='center')  # Rotate if names are long
plt.xlabel('REF')
plt.ylabel('HGHT')
plt.title('star2')

plt.tight_layout()
plt.show()
